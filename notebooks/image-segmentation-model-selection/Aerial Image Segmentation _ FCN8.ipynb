# %% [markdown]
# <a name='1'></a>
# # **1. Import Required Packages**

# %% [markdown]
# ### **1.1. Import Custom Packages**

# %%
############################################################################
# Mount Google Drive to /content/drive' and set default module path
############################################################################
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
############################################################################
# Set default module path
############################################################################
import sys
sys.path.insert(0,'/content/drive/My Drive/Colab Notebooks/aerial-image-segmentation-with-unet/modules')

# %%
############################################################################
# Import custom packages
############################################################################
# Data loading and preprocessing functions
from tf_keras_image_segmentation_models.preprocessing import list_image_paths
from tf_keras_image_segmentation_models.preprocessing import data_generator
from tf_keras_image_segmentation_models.preprocessing import display

# Model function
from tf_keras_image_segmentation_models.models.fcn import fcn

# Evaluation metrics functions
from tf_keras_image_segmentation_models.metrics import IoU
from tf_keras_image_segmentation_models.metrics import classification_report
from tf_keras_image_segmentation_models.predict import predict_mask
from tf_keras_image_segmentation_models.predict import show_predictions

# %% [markdown]
# ### **1.2. Import Other Packages**

# %%
import numpy as np
import imageio
import random
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model, load_model
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <a name='2'></a>
# # **2. Load and Preprocess Dataset**
#
# The Aeroscape dataset consists of 3269 images and their segmenatation labels (masks). As part of the data preparation step, we will load images and masks from all the five directories and carry out the a few preprocessing steps to ensure we provide our model with quality dataset.

# %% [markdown]
# <a name='2-1'></a>
# ### **2.1. Load the images and masks from their directories**

# %%
dataset_directory = '/content/drive/My Drive/Colab Notebooks/aerial-image-segmentation-with-unet/dataset/aeroscapes/'
image_directory_path = dataset_directory + 'JPEGImages'
mask_directory_path = dataset_directory + 'SegmentationClass'

# %%
# Use the 'list_image_paths' function to extract image and segmentation filepaths 
# from their directories
image_paths, mask_paths = list_image_paths(image_directory_path, mask_directory_path) 
number_of_images, number_of_masks = len(image_paths), len(mask_paths)
print(f"1. There are {number_of_images} images and {number_of_masks} masks in our dataset")
print(f"2. An example of an image path is: \n {image_paths[1]}")
print(f"3. An example of a mask path is: \n {mask_paths[1]}")
# Out:
# 1. There are 3269 images and 3269 masks in our dataset
# 2. An example of an image path is:
#  /content/drive/My Drive/Colab Notebooks/aerial-image-segmentation-with-unet/dataset/aeroscapes/JPEGImages/000001_071.jpg
# 3. An example of a mask path is:
#  /content/drive/My Drive/Colab Notebooks/aerial-image-segmentation-with-unet/dataset/aeroscapes/SegmentationClass/000001_071.png

# %% [markdown]
# <a name='2-2'></a>
# ### **2.2. Split the image and mask paths into training, validation, and test sets**

# %%
# First split the image paths into training and validation sets
train_image_paths, val_image_paths, train_mask_paths, val_mask_paths = train_test_split(image_paths, mask_paths, train_size=0.8, random_state=42)

# Keep part of the validation set as test set
validation_image_paths, test_image_paths, validation_mask_paths, test_mask_paths = train_test_split(val_image_paths, val_mask_paths, train_size = 0.60, random_state=42)

print(f'There are {len(train_image_paths)} images in the Training Set')
print(f'There are {len(validation_image_paths)} images in the Validation Set')
print(f'There are {len(test_image_paths)} images in the Test Set')
# Out:
# There are 2615 images in the Training Set
# There are 392 images in the Validation Set
# There are 262 images in the Test Set

# %% [markdown]
# <a name='2-3'></a>
# ### **2.3. - Create data generation pipelines to read and preprocess our data**
#
# We will be using the tf.data.Dataset API to load our images and masks for our model to process. The Dataset API allows us to build an asynchronous, highly optimized data pipeline to prevent our GPU from data starvation. It loads data from the disk (images or text), applies optimized transformations, creates batches and sends it to the GPU. Unlike former data pipelines made the GPU, the Dataset API wait for the CPU to load the data, leading to performance issues.
#
# To do this, we will be using a pre-defined 'data_generator' function.

# %%
# Define Variables 
batch_size = 32
buffer_size = 5120
image_size = (128,128)
image_channels =3
cache_dataset = True
shuffle_dataset = True
augment=True 
augment_type="horizontal_and_vertical"

# Create Data Generator Pipelines
train_dataset = data_generator(train_image_paths, train_mask_paths, 
                               image_size=image_size, image_channels=image_channels, 
                               batch_size=batch_size, cache_dataset=cache_dataset, 
                               shuffle_dataset=shuffle_dataset, buffer_size=buffer_size,
                               augment=augment, augment_type=augment_type)
validation_dataset = data_generator(validation_image_paths, validation_mask_paths, 
                               image_size=image_size, image_channels=image_channels, 
                               batch_size=batch_size, cache_dataset=cache_dataset, 
                               shuffle_dataset=shuffle_dataset, buffer_size=buffer_size)
test_dataset = data_generator(test_image_paths, test_mask_paths, 
                               image_size=image_size, image_channels=image_channels, 
                               batch_size=batch_size, cache_dataset=cache_dataset, 
                               shuffle_dataset=shuffle_dataset, buffer_size=buffer_size)

# %% [markdown]
# #### **2.2.4. Preview sample images and masks from the three dataset categories**

# %%
# Take a batch (32 images and their segmentation labels from each category of data)
for train_images, train_masks in train_dataset:
    break
for validation_images, validation_masks in validation_dataset:
    break
for test_images, test_masks in test_dataset:
    break
    
train_list = [train_images[0], train_masks[0]]
validation_list = [validation_images[0], validation_masks[0]]
test_list = [test_images[0], test_masks[0]]


display(train_list, figsize=(10, 10))
display(validation_list, figsize=(10, 10))
display(test_list, figsize=(10, 10))

# %% [markdown]
# <a name='3'></a>
# # **3. Model Architecture, Training, Evaluation and Prediction**

# %% [markdown]
# ## **3.1. Model Architecture and Training**

# %%
model = fcn(num_classes=12,
            model_type='fcn8',
            encoder_type='MobileNetV2',
            input_shape=(128, 128, 3),
            model_weights=None,
            encoder_weights='imagenet',
            encoder_freeze=False,
            decoder_type='transpose',
            output_activation='softmax')

#model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# 9420800/9406464 [==============================] - 0s 0us/step

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy',factor=1e-1, patience=10, verbose=1, min_lr = 2e-6)
batch_size = 64
epochs = 50

# %%
history = model.fit(train_dataset, 
                    validation_data = validation_dataset, 
                    epochs = epochs, 
                    verbose=1, 
                    callbacks = [reduce_lr], 
                    batch_size = batch_size,
                    shuffle = True)
# Out:
# Epoch 1/50
# 82/82 [==============================] - 1006s 2s/step - loss: 0.9484 - accuracy: 0.6590 - val_loss: 6.8617 - val_accuracy: 0.3364 - lr: 0.0010
# Epoch 2/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.4156 - accuracy: 0.8606 - val_loss: 4.7800 - val_accuracy: 0.3847 - lr: 0.0010
# Epoch 3/50
# 82/82 [==============================] - 12s 152ms/step - loss: 0.3540 - accuracy: 0.8816 - val_loss: 5.1754 - val_accuracy: 0.2605 - lr: 0.0010
# Epoch 4/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.2815 - accuracy: 0.9052 - val_loss: 4.6199 - val_accuracy: 0.3514 - lr: 0.0010
# Epoch 5/50
# 82/82 [==============================] - 12s 150ms/step - loss: 0.2484 - accuracy: 0.9159 - val_loss: 4.3265 - val_accuracy: 0.3512 - lr: 0.0010
# Epoch 6/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.2377 - accuracy: 0.9192 - val_loss: 4.3364 - val_accuracy: 0.3592 - lr: 0.0010
# Epoch 7/50
# 82/82 [==============================] - 12s 152ms/step - loss: 0.2183 - accuracy: 0.9252 - val_loss: 3.5206 - val_accuracy: 0.3858 - lr: 0.0010
# Epoch 8/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.2080 - accuracy: 0.9286 - val_loss: 2.4313 - val_accuracy: 0.4261 - lr: 0.0010
# Epoch 9/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.2357 - accuracy: 0.9195 - val_loss: 3.7995 - val_accuracy: 0.3658 - lr: 0.0010
# Epoch 10/50
# 82/82 [==============================] - 12s 150ms/step - loss: 0.1955 - accuracy: 0.9324 - val_loss: 3.9372 - val_accuracy: 0.3681 - lr: 0.0010
# Epoch 11/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1779 - accuracy: 0.9380 - val_loss: 3.9952 - val_accuracy: 0.3772 - lr: 0.0010
# Epoch 12/50
# 82/82 [==============================] - 12s 150ms/step - loss: 0.1721 - accuracy: 0.9399 - val_loss: 3.9168 - val_accuracy: 0.3747 - lr: 0.0010
# Epoch 13/50
# 82/82 [==============================] - 12s 152ms/step - loss: 0.1676 - accuracy: 0.9412 - val_loss: 4.6837 - val_accuracy: 0.3665 - lr: 0.0010
# Epoch 14/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1590 - accuracy: 0.9440 - val_loss: 3.9546 - val_accuracy: 0.3991 - lr: 0.0010
# Epoch 15/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1574 - accuracy: 0.9446 - val_loss: 3.3931 - val_accuracy: 0.4332 - lr: 0.0010
# Epoch 16/50
# 82/82 [==============================] - 12s 150ms/step - loss: 0.1570 - accuracy: 0.9445 - val_loss: 3.9106 - val_accuracy: 0.4219 - lr: 0.0010
# Epoch 17/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1556 - accuracy: 0.9446 - val_loss: 2.8944 - val_accuracy: 0.5036 - lr: 0.0010
# Epoch 18/50
# 82/82 [==============================] - 12s 150ms/step - loss: 0.1493 - accuracy: 0.9468 - val_loss: 2.4385 - val_accuracy: 0.5537 - lr: 0.0010
# Epoch 19/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1423 - accuracy: 0.9490 - val_loss: 2.1969 - val_accuracy: 0.5847 - lr: 0.0010
# Epoch 20/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1377 - accuracy: 0.9504 - val_loss: 2.0130 - val_accuracy: 0.6137 - lr: 0.0010
# Epoch 21/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1357 - accuracy: 0.9510 - val_loss: 1.3643 - val_accuracy: 0.6643 - lr: 0.0010
# Epoch 22/50
# 82/82 [==============================] - 12s 150ms/step - loss: 0.1338 - accuracy: 0.9514 - val_loss: 1.5756 - val_accuracy: 0.6674 - lr: 0.0010
# Epoch 23/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1336 - accuracy: 0.9516 - val_loss: 1.4596 - val_accuracy: 0.6806 - lr: 0.0010
# Epoch 24/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1354 - accuracy: 0.9506 - val_loss: 1.4600 - val_accuracy: 0.7010 - lr: 0.0010
# Epoch 25/50
# 82/82 [==============================] - 12s 152ms/step - loss: 0.1274 - accuracy: 0.9534 - val_loss: 1.2142 - val_accuracy: 0.7151 - lr: 0.0010
# Epoch 26/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1251 - accuracy: 0.9541 - val_loss: 0.9282 - val_accuracy: 0.7743 - lr: 0.0010
# Epoch 27/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1244 - accuracy: 0.9543 - val_loss: 0.7012 - val_accuracy: 0.8081 - lr: 0.0010
# Epoch 28/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1239 - accuracy: 0.9544 - val_loss: 0.7584 - val_accuracy: 0.8044 - lr: 0.0010
# Epoch 29/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1222 - accuracy: 0.9550 - val_loss: 0.5671 - val_accuracy: 0.8396 - lr: 0.0010
# Epoch 30/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1226 - accuracy: 0.9548 - val_loss: 0.4675 - val_accuracy: 0.8598 - lr: 0.0010
# Epoch 31/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1183 - accuracy: 0.9563 - val_loss: 0.3815 - val_accuracy: 0.8866 - lr: 0.0010
# Epoch 32/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1191 - accuracy: 0.9560 - val_loss: 0.3874 - val_accuracy: 0.8834 - lr: 0.0010
# Epoch 33/50
# 82/82 [==============================] - 12s 152ms/step - loss: 0.1190 - accuracy: 0.9560 - val_loss: 0.3310 - val_accuracy: 0.9015 - lr: 0.0010
# Epoch 34/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1173 - accuracy: 0.9565 - val_loss: 0.3393 - val_accuracy: 0.8978 - lr: 0.0010
# Epoch 35/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1145 - accuracy: 0.9575 - val_loss: 0.3230 - val_accuracy: 0.9045 - lr: 0.0010
# Epoch 36/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1114 - accuracy: 0.9585 - val_loss: 0.3748 - val_accuracy: 0.8911 - lr: 0.0010
# Epoch 37/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1110 - accuracy: 0.9586 - val_loss: 0.3103 - val_accuracy: 0.9096 - lr: 0.0010
# Epoch 38/50
# 82/82 [==============================] - 12s 152ms/step - loss: 0.1109 - accuracy: 0.9586 - val_loss: 0.2973 - val_accuracy: 0.9130 - lr: 0.0010
# Epoch 39/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1110 - accuracy: 0.9586 - val_loss: 0.2457 - val_accuracy: 0.9237 - lr: 0.0010
# Epoch 40/50
# 82/82 [==============================] - 12s 152ms/step - loss: 0.2091 - accuracy: 0.9276 - val_loss: 11.8018 - val_accuracy: 0.3782 - lr: 0.0010
# Epoch 41/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1748 - accuracy: 0.9378 - val_loss: 1.9730 - val_accuracy: 0.5914 - lr: 0.0010
# Epoch 42/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1350 - accuracy: 0.9509 - val_loss: 0.7234 - val_accuracy: 0.8044 - lr: 0.0010
# Epoch 43/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1260 - accuracy: 0.9540 - val_loss: 0.5617 - val_accuracy: 0.8294 - lr: 0.0010
# Epoch 44/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1383 - accuracy: 0.9493 - val_loss: 0.4698 - val_accuracy: 0.8709 - lr: 0.0010
# Epoch 45/50
# 82/82 [==============================] - 12s 152ms/step - loss: 0.1187 - accuracy: 0.9563 - val_loss: 0.3694 - val_accuracy: 0.8925 - lr: 0.0010
# Epoch 46/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1130 - accuracy: 0.9582 - val_loss: 0.3174 - val_accuracy: 0.9072 - lr: 0.0010
# Epoch 47/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1103 - accuracy: 0.9591 - val_loss: 0.2736 - val_accuracy: 0.9141 - lr: 0.0010
# Epoch 48/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1083 - accuracy: 0.9598 - val_loss: 0.2447 - val_accuracy: 0.9225 - lr: 0.0010
# Epoch 49/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1061 - accuracy: 0.9605 - val_loss: 0.2335 - val_accuracy: 0.9258 - lr: 0.0010
# Epoch 50/50
# 82/82 [==============================] - 12s 151ms/step - loss: 0.1064 - accuracy: 0.9603 - val_loss: 0.2402 - val_accuracy: 0.9251 - lr: 0.0010

# %%
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ## **3.2 Model Evaluation**

# %%
true_train_masks, predicted_train_masks = predict_mask(train_dataset, model)
true_validation_masks, predicted_validation_masks = predict_mask(validation_dataset, model)
true_test_masks, predicted_test_masks = predict_mask(test_dataset, model)

# %%
target_names = ['Background', 'Person', 'Bike', 'Car', 'Drone', 'Boat', 'Animal', 'Obstacle', 'Construction', 'Vegetation', 'Road', 'Sky']
train_report = classification_report(true_train_masks, 
                                     predicted_train_masks, 
                                     num_classes=12,
                                     metrics=["TP", "TN", "FP", "FN", "Recall", "Precision", "Sensitivity", "Specificity", "IoU", "TDR", "F1Score"], 
                                     target_names=target_names, 
                                     report_type = 'table', 
                                     table_type='tabulate-table', 
                                     show_mean_evaluations=True,
                                     show_classwise_evaluations=True)

train_report
# Out:
# ╒══════════════╤══════════╤═══════════╤═════════╤═════════╤══════════╤═════════════╤═══════════════╤═══════════════╤═══════╤═══════╤═══════════╕
# │ Evaluation   │ TP       │ TN        │ FP      │ FN      │   Recall │   Precision │   Sensitivity │   Specificity │   IoU │   TDR │   F1Score │
# ╞══════════════╪══════════╪═══════════╪═════════╪═════════╪══════════╪═════════════╪═══════════════╪═══════════════╪═══════╪═══════╪═══════════╡
# │ Overall      │ 40280754 │ 468722354 │ 2563406 │ 2563406 │     0.94 │        0.94 │          0.08 │          0.99 │  0.89 │  0.08 │      0.94 │
# ├──────────────┼──────────┼───────────┼─────────┼─────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Mean         │ -        │ -         │ -       │ -       │     0.68 │        0.73 │          0.08 │          0.99 │  0.56 │  0.08 │      0.71 │
# ├──────────────┼──────────┼───────────┼─────────┼─────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Background   │ 8623340  │ 32511196  │ 477240  │ 1232384 │     0.87 │        0.95 │          0.21 │          0.99 │  0.83 │  0.21 │      0.91 │
# ├──────────────┼──────────┼───────────┼─────────┼─────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Person       │ 129739   │ 42488820  │ 191751  │ 33850   │     0.79 │        0.4  │          0    │          1    │  0.37 │  0    │      0.53 │
# ├──────────────┼──────────┼───────────┼─────────┼─────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Bike         │ 1605     │ 42819632  │ 2126    │ 20797   │     0.07 │        0.43 │          0    │          1    │  0.07 │  0    │      0.12 │
# ├──────────────┼──────────┼───────────┼─────────┼─────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Car          │ 115559   │ 42654167  │ 29675   │ 44759   │     0.72 │        0.8  │          0    │          1    │  0.61 │  0    │      0.76 │
# ├──────────────┼──────────┼───────────┼─────────┼─────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Drone        │ 5655     │ 42828862  │ 2291    │ 7352    │     0.43 │        0.71 │          0    │          1    │  0.37 │  0    │      0.54 │
# ├──────────────┼──────────┼───────────┼─────────┼─────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Boat         │ 8332     │ 42824152  │ 10520   │ 1156    │     0.88 │        0.44 │          0    │          1    │  0.42 │  0    │      0.59 │
# ├──────────────┼──────────┼───────────┼─────────┼─────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Animal       │ 6391     │ 42806298  │ 761     │ 30710   │     0.17 │        0.89 │          0    │          1    │  0.17 │  0    │      0.29 │
# ├──────────────┼──────────┼───────────┼─────────┼─────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Obstacle     │ 122346   │ 42366155  │ 238272  │ 117387  │     0.51 │        0.34 │          0    │          0.99 │  0.26 │  0    │      0.41 │
# ├──────────────┼──────────┼───────────┼─────────┼─────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Construction │ 1609037  │ 40761803  │ 157321  │ 315999  │     0.84 │        0.91 │          0.04 │          1    │  0.77 │  0.04 │      0.87 │
# ├──────────────┼──────────┼───────────┼─────────┼─────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Vegetation   │ 15601853 │ 26022958  │ 822659  │ 396690  │     0.98 │        0.95 │          0.37 │          0.97 │  0.93 │  0.37 │      0.96 │
# ├──────────────┼──────────┼───────────┼─────────┼─────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Road         │ 12127510 │ 29804207  │ 607922  │ 304521  │     0.98 │        0.95 │          0.29 │          0.98 │  0.93 │  0.29 │      0.96 │
# ├──────────────┼──────────┼───────────┼─────────┼─────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Sky          │ 1929387  │ 40834104  │ 22868   │ 57801   │     0.97 │        0.99 │          0.05 │          1    │  0.96 │  0.05 │      0.98 │
# ╘══════════════╧══════════╧═══════════╧═════════╧═════════╧══════════╧═════════════╧═══════════════╧═══════════════╧═══════╧═══════╧═══════════╛

# %%
validation_report = classification_report(true_validation_masks, 
                                          predicted_validation_masks, 
                                          num_classes=12,
                                          metrics=["TP", "TN", "FP", "FN", "Recall", "Precision", "Sensitivity", "Specificity", "IoU", "TDR", "F1Score"],
                                          target_names=target_names,
                                          report_type = 'table', 
                                          table_type='tabulate-table',
                                          show_mean_evaluations=True,
                                          show_classwise_evaluations=True)

validation_report
# Out:
# ╒══════════════╤═════════╤══════════╤════════╤════════╤══════════╤═════════════╤═══════════════╤═══════════════╤═══════╤═══════╤═══════════╕
# │ Evaluation   │ TP      │ TN       │ FP     │ FN     │   Recall │   Precision │   Sensitivity │   Specificity │   IoU │   TDR │   F1Score │
# ╞══════════════╪═════════╪══════════╪════════╪════════╪══════════╪═════════════╪═══════════════╪═══════════════╪═══════╪═══════╪═══════════╡
# │ Overall      │ 5941480 │ 70166760 │ 481048 │ 481048 │     0.93 │        0.93 │          0.08 │          0.99 │  0.86 │  0.08 │      0.93 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Mean         │ -       │ -        │ -      │ -      │     0.61 │        0.65 │          0.08 │          0.99 │  0.49 │  0.08 │      0.63 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Background   │ 1308996 │ 4777906  │ 104417 │ 231209 │     0.85 │        0.93 │          0.22 │          0.98 │  0.8  │  0.22 │      0.89 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Person       │ 20432   │ 6360220  │ 31933  │ 9943   │     0.67 │        0.39 │          0    │          1    │  0.33 │  0    │      0.49 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Bike         │ 147     │ 6418809  │ 266    │ 3306   │     0.04 │        0.36 │          0    │          1    │  0.04 │  0    │      0.08 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Car          │ 13431   │ 6396307  │ 4851   │ 7939   │     0.63 │        0.73 │          0    │          1    │  0.51 │  0    │      0.68 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Drone        │ 441     │ 6420730  │ 309    │ 1048   │     0.3  │        0.59 │          0    │          1    │  0.25 │  0    │      0.39 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Boat         │ 1011    │ 6418713  │ 2400   │ 404    │     0.71 │        0.3  │          0    │          1    │  0.27 │  0    │      0.42 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Animal       │ 327     │ 6419319  │ 269    │ 2613   │     0.11 │        0.55 │          0    │          1    │  0.1  │  0    │      0.18 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Obstacle     │ 15671   │ 6339056  │ 44637  │ 23164  │     0.4  │        0.26 │          0    │          0.99 │  0.19 │  0    │      0.32 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Construction │ 189708  │ 6139162  │ 29222  │ 64436  │     0.75 │        0.87 │          0.03 │          1    │  0.67 │  0.03 │      0.8  │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Vegetation   │ 2276037 │ 3933138  │ 142372 │ 70981  │     0.97 │        0.94 │          0.37 │          0.97 │  0.91 │  0.37 │      0.96 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Road         │ 1845248 │ 4405969  │ 115791 │ 55520  │     0.97 │        0.94 │          0.3  │          0.97 │  0.92 │  0.3  │      0.96 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Sky          │ 270031  │ 6137431  │ 4581   │ 10485  │     0.96 │        0.98 │          0.04 │          1    │  0.95 │  0.04 │      0.97 │
# ╘══════════════╧═════════╧══════════╧════════╧════════╧══════════╧═════════════╧═══════════════╧═══════════════╧═══════╧═══════╧═══════════╛

# %%
test_report = classification_report(true_test_masks, 
                                    predicted_test_masks, 
                                    num_classes=12,
                                    metrics=["TP", "TN", "FP", "FN", "Recall", "Precision", "Sensitivity", "Specificity", "IoU", "TDR", "F1Score"],
                                    target_names=target_names, 
                                    report_type = 'table', 
                                    table_type='tabulate-table', 
                                    show_mean_evaluations=True,
                                    show_classwise_evaluations=True)

test_report
# Out:
# ╒══════════════╤═════════╤══════════╤════════╤════════╤══════════╤═════════════╤═══════════════╤═══════════════╤═══════╤═══════╤═══════════╕
# │ Evaluation   │ TP      │ TN       │ FP     │ FN     │   Recall │   Precision │   Sensitivity │   Specificity │   IoU │   TDR │   F1Score │
# ╞══════════════╪═════════╪══════════╪════════╪════════╪══════════╪═════════════╪═══════════════╪═══════════════╪═══════╪═══════╪═══════════╡
# │ Overall      │ 3966417 │ 46892497 │ 326191 │ 326191 │     0.92 │        0.92 │          0.08 │          0.99 │  0.86 │  0.08 │      0.92 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Mean         │ -       │ -        │ -      │ -      │     0.61 │        0.71 │          0.08 │          0.99 │  0.49 │  0.08 │      0.65 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Background   │ 725129  │ 3348909  │ 76417  │ 142153 │     0.84 │        0.9  │          0.18 │          0.98 │  0.77 │  0.18 │      0.87 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Person       │ 15101   │ 4250472  │ 20437  │ 6598   │     0.7  │        0.42 │          0    │          1    │  0.36 │  0    │      0.53 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Bike         │ 178     │ 4289832  │ 209    │ 2389   │     0.07 │        0.46 │          0    │          1    │  0.06 │  0    │      0.12 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Car          │ 9205    │ 4272518  │ 4075   │ 6810   │     0.57 │        0.69 │          0    │          1    │  0.46 │  0    │      0.63 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Drone        │ 240     │ 4291458  │ 55     │ 855    │     0.22 │        0.81 │          0    │          1    │  0.21 │  0    │      0.35 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Boat         │ 529     │ 4290923  │ 959    │ 197    │     0.73 │        0.36 │          0    │          1    │  0.31 │  0    │      0.48 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Animal       │ 284     │ 4287660  │ 55     │ 4609   │     0.06 │        0.84 │          0    │          1    │  0.06 │  0    │      0.11 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Obstacle     │ 10602   │ 4238365  │ 30857  │ 12784  │     0.45 │        0.26 │          0    │          0.99 │  0.2  │  0    │      0.33 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Construction │ 154295  │ 4062669  │ 21210  │ 54434  │     0.74 │        0.88 │          0.04 │          0.99 │  0.67 │  0.04 │      0.8  │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Vegetation   │ 1534761 │ 2620034  │ 94959  │ 42854  │     0.97 │        0.94 │          0.37 │          0.97 │  0.92 │  0.37 │      0.96 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Road         │ 1334576 │ 2839549  │ 73383  │ 45100  │     0.97 │        0.95 │          0.32 │          0.97 │  0.92 │  0.32 │      0.96 │
# ├──────────────┼─────────┼──────────┼────────┼────────┼──────────┼─────────────┼───────────────┼───────────────┼───────┼───────┼───────────┤
# │ Sky          │ 181517  │ 4100108  │ 3575   │ 7408   │     0.96 │        0.98 │          0.04 │          1    │  0.94 │  0.04 │      0.97 │
# ╘══════════════╧═════════╧══════════╧════════╧════════╧══════════╧═════════════╧═══════════════╧═══════════════╧═══════╧═══════╧═══════════╛

# %% [markdown]
# ## **3.3. Predict image segmentations using the trained Model**

# %% [markdown]
# #### **3.3.1. Predict and compare masks of images in the training set**

# %%
show_predictions(train_dataset, model, num_batches=6, num_per_batch=1, random_state=True)

# %% [markdown]
# #### **3.3.2. Predict and compare masks of images in the validation set**

# %%
show_predictions(validation_dataset, model, num_batches=6, num_per_batch=1, random_state=True)

# %% [markdown]
# #### **3.3.3. Predict and compare masks of images in the test set**

# %%
show_predictions(test_dataset, model, num_batches=6, num_per_batch=1, random_state=True)
